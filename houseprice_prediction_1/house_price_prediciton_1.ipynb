# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x = data.drop(['median_house_value'] , axis=1)
y = data['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2)

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4822     -118.31     34.05                35.0       2007.0           571.0
# 14188    -117.06     32.71                11.0       2397.0           523.0
# 15233    -117.23     33.01                18.0       3961.0           511.0
# 14999    -117.03     32.74                35.0       1878.0           454.0
# 7967     -118.19     33.86                36.0       2013.0           546.0
# ...          ...       ...                 ...          ...             ...
# 11610    -118.05     33.78                25.0       2356.0           330.0
# 11029    -117.83     33.79                25.0       2070.0           513.0
# 15153    -117.04     33.01                28.0        922.0           107.0
# 14024    -117.15     32.76                43.0       2361.0           489.0
# 10611    -117.79     33.68                 9.0       1633.0           295.0
#
#        population  households  median_income ocean_proximity
# 4822       1513.0       554.0         2.1162       <1H OCEAN
# 14188      1566.0       514.0         3.8687      NEAR OCEAN
# 15233      1541.0       470.0        11.1118      NEAR OCEAN
# 14999       991.0       409.0         2.4345      NEAR OCEAN
# 7967       1659.0       522.0         3.1215       <1H OCEAN
# ...           ...         ...            ...             ...
# 11610       937.0       326.0         6.6264       <1H OCEAN
# 11029      1078.0       460.0         2.9312       <1H OCEAN
# 15153       314.0        97.0         8.4721       <1H OCEAN
# 14024       824.0       470.0         3.4196      NEAR OCEAN
# 10611       928.0       297.0         5.7858       <1H OCEAN
#
# [16346 rows x 9 columns]

# %%
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5684     -118.28     33.68                 8.0       2842.0           522.0
# 7667     -118.08     33.93                39.0       1478.0           324.0
# 430      -122.28     37.88                52.0       1172.0           215.0
# 4677     -118.34     34.08                52.0       1421.0           163.0
# 2794     -117.90     36.95                19.0         99.0            26.0
# ...          ...       ...                 ...          ...             ...
# 8806     -118.35     33.74                25.0       8272.0          1132.0
# 17513    -121.92     37.33                52.0       2009.0           338.0
# 1189     -121.52     39.43                15.0       2119.0           389.0
# 17221    -119.71     34.45                35.0       2183.0           363.0
# 17584    -121.93     37.31                29.0       1377.0           430.0
#
#        population  households  median_income ocean_proximity
# 5684       1624.0       510.0         3.7282      NEAR OCEAN
# 7667       1127.0       320.0         3.5250       <1H OCEAN
# 430         489.0       218.0         3.9167        NEAR BAY
# 4677        495.0       167.0        10.5860       <1H OCEAN
# 2794         51.0        22.0         1.7292          INLAND
# ...           ...         ...            ...             ...
# 8806       3392.0      1132.0        10.0973      NEAR OCEAN
# 17513       841.0       338.0         5.5259       <1H OCEAN
# 1189       1079.0       374.0         2.3566          INLAND
# 17221       988.0       351.0         5.5922       <1H OCEAN
# 17584       969.0       399.0         2.6573       <1H OCEAN
#
# [4087 rows x 9 columns]

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1206     -121.71     39.41                22.0       1814.0           342.0
# 5352     -118.40     34.04                42.0       1298.0           174.0
# 12124    -117.24     33.94                15.0       1569.0           423.0
# 17676    -121.84     37.32                14.0       5762.0          1538.0
# 19974    -118.82     36.13                43.0       1281.0           287.0
# ...          ...       ...                 ...          ...             ...
# 17508    -121.90     37.34                50.0       1345.0           287.0
# 19350    -122.94     38.57                33.0       1530.0           266.0
# 865      -122.04     37.58                14.0      14917.0          2708.0
# 4367     -118.27     34.10                41.0       3729.0           740.0
# 9348     -122.56     37.98                36.0       2649.0           542.0
#
#        population  households  median_income ocean_proximity  \
# 1206        941.0       323.0         2.1728          INLAND
# 5352        420.0       190.0        12.8483       <1H OCEAN
# 12124      1123.0       369.0         1.6111          INLAND
# 17676      3979.0      1389.0         3.6953       <1H OCEAN
# 19974       534.0       231.0         2.8906          INLAND
# ...           ...         ...            ...             ...
# 17508       791.0       254.0         3.5966       <1H OCEAN
# 19350       728.0       250.0         5.1005       <1H OCEAN
# 865        8012.0      2606.0         5.6277        NEAR BAY
# 4367       1364.0       707.0         5.7778       <1H OCEAN
# 9348       1111.0       557.0         4.8056        NEAR BAY
#
#        median_house_value
# 1206              59400.0
# 5352             500001.0
# 12124            113900.0
# 17676            192600.0
# 19974             65700.0
# ...                   ...
# 17508            245800.0
# 19350            266700.0
# 865              269800.0
# 4367             412700.0
# 9348             345700.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15 , 9))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1206     -121.71     39.41                22.0       1814.0           342.0
# 5352     -118.40     34.04                42.0       1298.0           174.0
# 12124    -117.24     33.94                15.0       1569.0           423.0
# 17676    -121.84     37.32                14.0       5762.0          1538.0
# 19974    -118.82     36.13                43.0       1281.0           287.0
# ...          ...       ...                 ...          ...             ...
# 17508    -121.90     37.34                50.0       1345.0           287.0
# 19350    -122.94     38.57                33.0       1530.0           266.0
# 865      -122.04     37.58                14.0      14917.0          2708.0
# 4367     -118.27     34.10                41.0       3729.0           740.0
# 9348     -122.56     37.98                36.0       2649.0           542.0
#
#        population  households  median_income ocean_proximity  \
# 1206        941.0       323.0         2.1728          INLAND
# 5352        420.0       190.0        12.8483       <1H OCEAN
# 12124      1123.0       369.0         1.6111          INLAND
# 17676      3979.0      1389.0         3.6953       <1H OCEAN
# 19974       534.0       231.0         2.8906          INLAND
# ...           ...         ...            ...             ...
# 17508       791.0       254.0         3.5966       <1H OCEAN
# 19350       728.0       250.0         5.1005       <1H OCEAN
# 865        8012.0      2606.0         5.6277        NEAR BAY
# 4367       1364.0       707.0         5.7778       <1H OCEAN
# 9348       1111.0       557.0         4.8056        NEAR BAY
#
#        median_house_value
# 1206              59400.0
# 5352             500001.0
# 12124            113900.0
# 17676            192600.0
# 19974             65700.0
# ...                   ...
# 17508            245800.0
# 19350            266700.0
# 865              269800.0
# 4367             412700.0
# 9348             345700.0
#
# [16346 rows x 10 columns]

# %%
non_train_data = train_data.select_dtypes(include=[np.number])
non_train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.923889           -0.105114     0.040234
# latitude            -0.923889  1.000000            0.006560    -0.033439
# housing_median_age  -0.105114  0.006560            1.000000    -0.356035
# total_rooms          0.040234 -0.033439           -0.356035     1.000000
# total_bedrooms       0.065343 -0.064597           -0.315837     0.930938
# population           0.093835 -0.104199           -0.288868     0.855700
# households           0.052540 -0.069300           -0.297931     0.918920
# median_income       -0.017169 -0.078543           -0.115974     0.195575
# median_house_value  -0.047356 -0.143300            0.109564     0.135696
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.065343    0.093835    0.052540      -0.017169
# latitude                 -0.064597   -0.104199   -0.069300      -0.078543
# housing_median_age       -0.315837   -0.288868   -0.297931      -0.115974
# total_rooms               0.930938    0.855700    0.918920       0.195575
# total_bedrooms            1.000000    0.876985    0.980226      -0.009745
# population                0.876985    1.000000    0.905802       0.001047
# households                0.980226    0.905802    1.000000       0.010731
# median_income            -0.009745    0.001047    0.010731       1.000000
# median_house_value        0.051850   -0.024502    0.066432       0.688768
#
#                     median_house_value
# longitude                    -0.047356
# latitude                     -0.143300
# housing_median_age            0.109564
# total_rooms                   0.135696
# total_bedrooms                0.051850
# population                   -0.024502
# households                    0.066432
# median_income                 0.688768
# median_house_value            1.000000

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1206     -121.71     39.41                22.0       1814.0           342.0
# 5352     -118.40     34.04                42.0       1298.0           174.0
# 12124    -117.24     33.94                15.0       1569.0           423.0
# 17676    -121.84     37.32                14.0       5762.0          1538.0
# 19974    -118.82     36.13                43.0       1281.0           287.0
# ...          ...       ...                 ...          ...             ...
# 17508    -121.90     37.34                50.0       1345.0           287.0
# 19350    -122.94     38.57                33.0       1530.0           266.0
# 865      -122.04     37.58                14.0      14917.0          2708.0
# 4367     -118.27     34.10                41.0       3729.0           740.0
# 9348     -122.56     37.98                36.0       2649.0           542.0
#
#        population  households  median_income ocean_proximity  \
# 1206        941.0       323.0         2.1728          INLAND
# 5352        420.0       190.0        12.8483       <1H OCEAN
# 12124      1123.0       369.0         1.6111          INLAND
# 17676      3979.0      1389.0         3.6953       <1H OCEAN
# 19974       534.0       231.0         2.8906          INLAND
# ...           ...         ...            ...             ...
# 17508       791.0       254.0         3.5966       <1H OCEAN
# 19350       728.0       250.0         5.1005       <1H OCEAN
# 865        8012.0      2606.0         5.6277        NEAR BAY
# 4367       1364.0       707.0         5.7778       <1H OCEAN
# 9348       1111.0       557.0         4.8056        NEAR BAY
#
#        median_house_value
# 1206              59400.0
# 5352             500001.0
# 12124            113900.0
# 17676            192600.0
# 19974             65700.0
# ...                   ...
# 17508            245800.0
# 19350            266700.0
# 865              269800.0
# 4367             412700.0
# 9348             345700.0
#
# [16346 rows x 10 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(non_train_data.corr() , annot = True , cmap ="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] +  1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] +  1)
train_data['population'] = np.log(train_data['population'] +  1)
train_data['households'] = np.log(train_data['households'] +  1)

# %%
train_data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7292
# INLAND        5143
# NEAR OCEAN    2113
# NEAR BAY      1793
# ISLAND           5
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 1206       False    True   False     False       False
# 5352        True   False   False     False       False
# 12124      False    True   False     False       False
# 17676       True   False   False     False       False
# 19974      False    True   False     False       False
# ...          ...     ...     ...       ...         ...
# 17508       True   False   False     False       False
# 19350       True   False   False     False       False
# 865        False   False   False      True       False
# 4367        True   False   False     False       False
# 9348       False   False   False      True       False
#
# [16346 rows x 5 columns]

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'] , axis = 1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1206     -121.71     39.41                22.0     7.503841        5.837730
# 5352     -118.40     34.04                42.0     7.169350        5.164786
# 12124    -117.24     33.94                15.0     7.358831        6.049733
# 17676    -121.84     37.32                14.0     8.659213        7.338888
# 19974    -118.82     36.13                43.0     7.156177        5.662960
# ...          ...       ...                 ...          ...             ...
# 17508    -121.90     37.34                50.0     7.204893        5.662960
# 19350    -122.94     38.57                33.0     7.333676        5.587249
# 865      -122.04     37.58                14.0     9.610324        7.904335
# 4367     -118.27     34.10                41.0     8.224164        6.608001
# 9348     -122.56     37.98                36.0     7.882315        6.297109
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 1206     6.848005    5.780744         2.1728             59400.0      False
# 5352     6.042633    5.252273        12.8483            500001.0       True
# 12124    7.024649    5.913503         1.6111            113900.0      False
# 17676    8.289037    7.237059         3.6953            192600.0       True
# 19974    6.282267    5.446737         2.8906             65700.0      False
# ...           ...         ...            ...                 ...        ...
# 17508    6.674561    5.541264         3.5966            245800.0       True
# 19350    6.591674    5.525453         5.1005            266700.0       True
# 865      8.988821    7.865955         5.6277            269800.0      False
# 4367     7.218910    6.562444         5.7778            412700.0       True
# 9348     7.013915    6.324359         4.8056            345700.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 1206     True   False     False       False
# 5352    False   False     False       False
# 12124    True   False     False       False
# 17676   False   False     False       False
# 19974    True   False     False       False
# ...       ...     ...       ...         ...
# 17508   False   False     False       False
# 19350   False   False     False       False
# 865     False   False      True       False
# 4367    False   False     False       False
# 9348    False   False      True       False
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr() , annot = True , cmap ="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15, 8))
sns.scatterplot(x="latitude" , y= "longitude" , data = train_data , hue = "median_house_value" , palette = "coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedrooom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms']/train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr() , annot = True , cmap ="YlGnBu")
# Out:
# <Axes: >

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4087 entries, 17889 to 35
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           4087 non-null   float64
#  1   latitude            4087 non-null   float64
#  2   housing_median_age  4087 non-null   float64
#  3   total_rooms         4087 non-null   float64
#  4   total_bedrooms      4087 non-null   float64
#  5   population          4087 non-null   float64
#  6   households          4087 non-null   float64
#  7   median_income       4087 non-null   float64
#  8   ocean_proximity     4087 non-null   object
# dtypes: float64(8), object(1)
# memory usage: 319.3+ KB

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16346 entries, 1206 to 9348
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16346 non-null  float64
#  1   latitude            16346 non-null  float64
#  2   housing_median_age  16346 non-null  float64
#  3   total_rooms         16346 non-null  float64
#  4   total_bedrooms      16346 non-null  float64
#  5   population          16346 non-null  float64
#  6   households          16346 non-null  float64
#  7   median_income       16346 non-null  float64
#  8   median_house_value  16346 non-null  float64
#  9   <1H OCEAN           16346 non-null  bool
#  10  INLAND              16346 non-null  bool
#  11  ISLAND              16346 non-null  bool
#  12  NEAR BAY            16346 non-null  bool
#  13  NEAR OCEAN          16346 non-null  bool
#  14  bedrooom_ratio      16346 non-null  float64
#  15  household_rooms     16346 non-null  float64
# dtypes: bool(5), float64(11)
# memory usage: 2.1 MB

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler


scaler = StandardScaler()


x_train , y_train = train_data.drop(['median_house_value'] , axis =1 ) , train_data['median_house_value']



reg = LinearRegression()

reg.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16346 entries, 14120 to 3295
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16346 non-null  float64
#  1   latitude            16346 non-null  float64
#  2   housing_median_age  16346 non-null  float64
#  3   total_rooms         16346 non-null  float64
#  4   total_bedrooms      16346 non-null  float64
#  5   population          16346 non-null  float64
#  6   households          16346 non-null  float64
#  7   median_income       16346 non-null  float64
#  8   <1H OCEAN           16346 non-null  bool
#  9   INLAND              16346 non-null  bool
#  10  ISLAND              16346 non-null  bool
#  11  NEAR BAY            16346 non-null  bool
#  12  NEAR OCEAN          16346 non-null  bool
#  13  bedrooom_ratio      16346 non-null  float64
#  14  household_rooms     16346 non-null  float64
# dtypes: bool(5), float64(10)
# memory usage: 2.0 MB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4087 entries, 16952 to 7196
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           4087 non-null   float64
#  1   latitude            4087 non-null   float64
#  2   housing_median_age  4087 non-null   float64
#  3   total_rooms         4087 non-null   float64
#  4   total_bedrooms      4087 non-null   float64
#  5   population          4087 non-null   float64
#  6   households          4087 non-null   float64
#  7   median_income       4087 non-null   float64
#  8   ocean_proximity     4087 non-null   object
# dtypes: float64(8), object(1)
# memory usage: 448.3+ KB

# %%
test_data = x_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] +  1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] +  1)
test_data['population'] = np.log(test_data['population'] +  1)
test_data['households'] = np.log(test_data['households'] +  1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'] , axis = 1)

test_data['bedrooom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms']/test_data['households']

# %%
x_test_s , y_test_s = test_data.drop(['median_house_value'] , axis =1 ) , test_data['median_house_value']

# %%
x_test.shape,y_test.shape
# Out:
# ((4087, 9), (4087,))

# %%
x_test_s = scaler.transform(x_test)

# %%
reg.score(x_test , y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[219], line 1
# ----> 1 reg.score(x_test , y_test)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:848, in RegressorMixin.score(self, X, y, sample_weight)
#     806 """Return the coefficient of determination of the prediction.
#     807
#     808 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     843 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     844 """
#     846 from .metrics import r2_score
# --> 848 y_pred = self.predict(X)
#     849 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py:286, in LinearModel.predict(self, X)
#     272 def predict(self, X):
#     273     """
#     274     Predict using the linear model.
#     275
#    (...)
#     284         Returns predicted values.
#     285     """
# --> 286     return self._decision_function(X)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py:269, in LinearModel._decision_function(self, X)
#     266 def _decision_function(self, X):
#     267     check_is_fitted(self)
# --> 269     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     270     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - ocean_proximity
# Feature names seen at fit time, yet now missing:
# - <1H OCEAN
# - INLAND
# - ISLAND
# - NEAR BAY
# - NEAR OCEAN
# - ...

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train_s , y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test_s , y_test)

# %%
from sklearn.model_selection import GridSearchCV


forest = RandomForestRegressor()
param_grid ={
    "n_estimators":[3,10,30],
    "max_features":[2,4,6,8]
}

grid_search = GridSearchCV(forest , param_grid , cv =5 , scoring="neg_mean_squared_error",
                           return_train_score = True)

grid_search.fit(x_train , y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=8, n_estimators=30)
